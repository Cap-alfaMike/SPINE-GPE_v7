# %% [markdown]
# # SPINE-GPE v7 — PNAD COVID Certification Engine v1.0.0
# Certificação da ponte pandêmica sem identificação falsa de plataforma.

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
from pathlib import Path
import subprocess, sys, json, shutil
ROOT = Path("/content/drive/MyDrive/aCidadeAlgoritmica/SPINE-GPEv7")
SCRIPT_CANDIDATES = [Path("/content/SPINE_GPEv7_PNAD_COVID_CERTIFIER_v1.0.0.py"), ROOT / "scripts/SPINE_GPEv7_PNAD_COVID_CERTIFIER_v1.0.0.py"]
REQ_CANDIDATES = [Path("/content/requirements_SPINE_GPEv7_PNAD_COVID_CERTIFIER_v1.0.0.txt"), ROOT / "scripts/requirements_SPINE_GPEv7_PNAD_COVID_CERTIFIER_v1.0.0.txt"]
SCRIPT = next((p for p in SCRIPT_CANDIDATES if p.exists()), SCRIPT_CANDIDATES[0])
REQ = next((p for p in REQ_CANDIDATES if p.exists()), REQ_CANDIDATES[0])
print("ROOT:", ROOT)
print("SCRIPT:", SCRIPT, SCRIPT.exists())
print("REQ:", REQ, REQ.exists())
if not SCRIPT.exists(): raise FileNotFoundError(f"Script não encontrado: {SCRIPT_CANDIDATES}")
if not REQ.exists(): raise FileNotFoundError(f"Requirements não encontrado: {REQ_CANDIDATES}")
# Out:
# ROOT: /content/drive/MyDrive/aCidadeAlgoritmica/SPINE-GPEv7
# SCRIPT: /content/drive/MyDrive/aCidadeAlgoritmica/SPINE-GPEv7/scripts/SPINE_GPEv7_PNAD_COVID_CERTIFIER_v1.0.0.py True
# REQ: /content/drive/MyDrive/aCidadeAlgoritmica/SPINE-GPEv7/scripts/requirements_SPINE_GPEv7_PNAD_COVID_CERTIFIER_v1.0.0.txt True

# %%
subprocess.run([sys.executable,"-m","pip","install","-q","--prefer-binary","-r",str(REQ)],check=True)
subprocess.run([sys.executable,"-m","py_compile",str(SCRIPT)],check=True)
print("py_compile: OK")
# Out:
# py_compile: OK

# %% [markdown]
# ## Auditoria — setembro de 2020

# %%
audit = subprocess.run([sys.executable,str(SCRIPT),"--root",str(ROOT),"--mode","audit","--months","9","--download","--strict"],text=True,capture_output=True)
print(audit.stdout); print(audit.stderr); print("Exit code:",audit.returncode)
# Out:
# 2026-07-21 00:15:22,399 | INFO | SPINE-GPE PNAD COVID Certifier v1.0.0 | root=/content/drive/MyDrive/aCidadeAlgoritmica/SPINE-GPEv7 | mode=audit | months=[9]
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/aCidadeAlgoritmica/SPINE-GPEv7/scripts/SPINE_GPEv7_PNAD_COVID_CERTIFIER_v1.0.0.py", line 1056, in <module>
#     raise SystemExit(main())
#                      ^^^^^^
#   File "/content/drive/MyDrive/aCidadeAlgoritmica/SPINE-GPEv7/scripts/SPINE_GPEv7_PNAD_COVID_CERTIFIER_v1.0.0.py", line 1051, in main
#     return audit_mode(root, args.months, args.download, args.strict, logger)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/aCidadeAlgoritmica/SPINE-GPEv7/scripts/SPINE_GPEv7_PNAD_COVID_CERTIFIER_v1.0.0.py", line 894, in audit_mode
#     source, dictionary = acquire_month(root, month, download, session, logger)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/aCidadeAlgoritmica/SPINE-GPEv7/scripts/SPINE_GPEv7_PNAD_COVID_CERTIFIER_v1.0.0.py", line 425, in acquire_month
#     dictionary = find_dictionary(root, month)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/aCidadeAlgoritmica/SPINE-GPEv7/scripts/SPINE_GPEv7_PNAD_COVID_CERTIFIER_v1.0.0.py", line 384, in find_dictionary
#     found.extend(directory.glob(f"**/{token}_*{suffix}"))
#   File "/usr/lib/python3.12/pathlib.py", line 1093, in glob
#     selector = _make_selector(tuple(pattern_parts), self._flavour, case_sensitive)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/pathlib.py", line 103, in _make_selector
#     return cls(pat, child_parts, flavour, case_sensitive)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/pathlib.py", line 226, in __init__
#     _Selector.__init__(self, child_parts, flavour, case_sensitive)
#   File "/usr/lib/python3.12/pathlib.py", line 158, in __init__
#     self.successor = _make_selector(child_parts, flavour, case_sensitive)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/pathlib.py", line 100, in _make_selector
#     raise ValueError("Invalid pattern: '**' can only be an entire path component")
# ValueError: Invalid pattern: '**' can only be an entire path component
#
# Exit code: 1

# %% [markdown]
# ## Certificação — setembro de 2020

# %%
cert = subprocess.run([sys.executable,str(SCRIPT),"--root",str(ROOT),"--mode","certify","--months","9","--download","--chunk-rows","50000","--strict"],text=True,capture_output=True)
print(cert.stdout); print(cert.stderr); print("Exit code:",cert.returncode)
# Out:
# 2026-07-21 00:16:04,165 | INFO | SPINE-GPE PNAD COVID Certifier v1.0.0 | root=/content/drive/MyDrive/aCidadeAlgoritmica/SPINE-GPEv7 | mode=certify | months=[9]
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/aCidadeAlgoritmica/SPINE-GPEv7/scripts/SPINE_GPEv7_PNAD_COVID_CERTIFIER_v1.0.0.py", line 1056, in <module>
#     raise SystemExit(main())
#                      ^^^^^^
#   File "/content/drive/MyDrive/aCidadeAlgoritmica/SPINE-GPEv7/scripts/SPINE_GPEv7_PNAD_COVID_CERTIFIER_v1.0.0.py", line 1052, in main
#     return certify_mode(root, args.months, args.download, args.strict, args.chunk_rows, args.cache_dir, logger)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/aCidadeAlgoritmica/SPINE-GPEv7/scripts/SPINE_GPEv7_PNAD_COVID_CERTIFIER_v1.0.0.py", line 931, in certify_mode
#     source, dictionary = acquire_month(root, month, download, session, logger)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/aCidadeAlgoritmica/SPINE-GPEv7/scripts/SPINE_GPEv7_PNAD_COVID_CERTIFIER_v1.0.0.py", line 425, in acquire_month
#     dictionary = find_dictionary(root, month)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/aCidadeAlgoritmica/SPINE-GPEv7/scripts/SPINE_GPEv7_PNAD_COVID_CERTIFIER_v1.0.0.py", line 384, in find_dictionary
#     found.extend(directory.glob(f"**/{token}_*{suffix}"))
#   File "/usr/lib/python3.12/pathlib.py", line 1093, in glob
#     selector = _make_selector(tuple(pattern_parts), self._flavour, case_sensitive)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/pathlib.py", line 103, in _make_selector
#     return cls(pat, child_parts, flavour, case_sensitive)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/pathlib.py", line 226, in __init__
#     _Selector.__init__(self, child_parts, flavour, case_sensitive)
#   File "/usr/lib/python3.12/pathlib.py", line 158, in __init__
#     self.successor = _make_selector(child_parts, flavour, case_sensitive)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/pathlib.py", line 100, in _make_selector
#     raise ValueError("Invalid pattern: '**' can only be an entire path component")
# ValueError: Invalid pattern: '**' can only be an entire path component
#
# Exit code: 1

# %%
LOCK = ROOT / "00_admin/PNAD_COVID_CERTIFICATION_LOCK.json"
lock=json.loads(LOCK.read_text(encoding="utf-8"))
print(json.dumps(lock,ensure_ascii=False,indent=2))
assert lock["status"] in {"CERTIFIED","CORE_CERTIFIED"}, lock["critical_failures"]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_515/1265065526.py in <cell line: 0>()
#       1 LOCK = ROOT / "00_admin/PNAD_COVID_CERTIFICATION_LOCK.json"
# ----> 2 lock=json.loads(LOCK.read_text(encoding="utf-8"))
#       3 print(json.dumps(lock,ensure_ascii=False,indent=2))
#       4 assert lock["status"] in {"CERTIFIED","CORE_CERTIFIED"}, lock["critical_failures"]
#
# /usr/lib/python3.12/pathlib.py in read_text(self, encoding, errors)
#    1025         """
#    1026         encoding = io.text_encoding(encoding)
# -> 1027         with self.open(mode='r', encoding=encoding, errors=errors) as f:
#    1028             return f.read()
#    1029
#
# /usr/lib/python3.12/pathlib.py in open(self, mode, buffering, encoding, errors, newline)
#    1011         if "b" not in mode:
#    1012             encoding = io.text_encoding(encoding)
# -> 1013         return io.open(self, mode, buffering, encoding, errors, newline)
#    1014
#    1015     def read_bytes(self):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/aCidadeAlgoritmica/SPINE-GPEv7/00_admin/PNAD_COVID_CERTIFICATION_LOCK.json'

# %% [markdown]
# ## Série completa maio–novembro (após validar setembro)

# %%
# full = subprocess.run([sys.executable,str(SCRIPT),"--root",str(ROOT),"--mode","certify","--months","all","--download","--chunk-rows","50000","--strict"],check=False)
