# %% [markdown]
# # SPINE-GPE v7 — PNAD COVID C014 Universe Auditor v1.0.0
# Auditoria leve do Parquet imutável certificado. Não relê microdados brutos.

# %%
from google.colab import drive
drive.mount('/content/drive')
from pathlib import Path
import subprocess, sys, json
ROOT = Path('/content/drive/MyDrive/aCidadeAlgoritmica/SPINE-GPEv7')
SCRIPT = ROOT / 'scripts' / 'SPINE_GPEv7_PNAD_COVID_C014_AUDITOR_v1.0.0.py'
REQ = ROOT / 'scripts' / 'requirements_SPINE_GPEv7_PNAD_COVID_C014_AUDITOR_v1.0.0.txt'
print(ROOT, SCRIPT.exists(), REQ.exists())
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/aCidadeAlgoritmica/SPINE-GPEv7 True True

# %%
subprocess.run([sys.executable, '-m', 'pip', 'install', '-q', '-r', str(REQ)], check=True)
subprocess.run([sys.executable, '-m', 'py_compile', str(SCRIPT)], check=True)
print('py_compile: OK')
# Out:
# py_compile: OK

# %%
audit = subprocess.run([sys.executable, str(SCRIPT), '--root', str(ROOT), '--strict'], text=True, capture_output=True, check=False)
print(audit.stdout)
print(audit.stderr)
print('Exit code:', audit.returncode)
assert audit.returncode == 0, audit.stderr
# Out:
# {
#   "run_id": "20260721T020957Z",
#   "script_version": "1.0.0",
#   "audit_schema_version": "spine-gpe-v7-pnad-covid-c014-audit-1.0.0",
#   "status": "AUDIT_PASSED",
#   "critical_failures": [],
#   "warnings": [
#     {
#       "test_id": "2020m05.c014.coverage",
#       "status": "WARN",
#       "severity": "high",
#       "message": "Cobertura C014 abaixo de 95%; interpretação permanece condicional às respostas válidas.",
#       "observed": 65.2241112828439,
#       "expected": ">=95%",
#       "evidence": null
#     },
#     {
#       "test_id": "2020m06.c014.coverage",
#       "status": "WARN",
#       "severity": "high",
#       "message": "Cobertura C014 abaixo de 95%; interpretação permanece condicional às respostas válidas.",
#       "observed": 66.11151339608979,
#       "expected": ">=95%",
#       "evidence": null
#     },
#     {
#       "test_id": "2020m07.c014.coverage",
#       "status": "WARN",
#       "severity": "high",
#       "message": "Cobertura C014 abaixo de 95%; interpretação permanece condicional às respostas válidas.",
#       "observed": 67.38044254104211,
#       "expected": ">=95%",
#       "evidence": null
#     },
#     {
#       "test_id": "2020m08.c014.coverage",
#       "status": "WARN",
#       "severity": "high",
#       "message": "Cobertura C014 abaixo de 95%; interpretação permanece condicional às respostas válidas.",
#       "observed": 66.27747252747253,
#       "expected": ">=95%",
#       "evidence": null
#     },
#     {
#       "test_id": "2020m09.c014.coverage",
#       "status": "WARN",
#       "severity": "high",
#       "message": "Cobertura C014 abaixo de 95%; interpretação permanece condicional às respostas válidas.",
#       "observed": 66.04296604296604,
#       "expected": ">=95%",
#       "evidence": null
#     },
#     {
#       "test_id": "2020m10.c014.coverage",
#       "status": "WARN",
#       "severity": "high",
#       "message": "Cobertura C014 abaixo de 95%; interpretação permanece condicional às respostas válidas.",
#       "observed": 67.67746381805651,
#       "expected": ">=95%",
#       "evidence": null
#     },
#     {
#       "test_id": "2020m11.c014.coverage",
#       "status": "WARN",
#       "severity": "high",
#       "message": "Cobertura C014 abaixo de 95%; interpretação permanece condicional às respostas válidas.",
#       "observed": 68.1046676096181,
#       "expected": ">=95%",
#       "evidence": null
#     }
#   ],
#   "input": "/content/drive/MyDrive/aCidadeAlgoritmica/SPINE-GPEv7/03_processed/20_pnad_covid_certified/certified_pnad_covid_delivery_2020_m05_m11_20260721T010633Z.parquet",
#   "input_sha256": "44af48a4ee05185778d264f528cf9e29863370ad038cfce6eeb10f174ff819ab",
#   "report": "/content/drive/MyDrive/aCidadeAlgoritmica/SPINE-GPEv7/06_reports/pnad_covid_certification/pnad_covid_c014_audit_report_20260721T020957Z.md",
#   "audit_json": "/content/drive/MyDrive/aCidadeAlgoritmica/SPINE-GPEv7/00_admin/registry/pnad_covid_c014_universe_audit_20260721T020957Z.json",
#   "position_delivery_month": "/content/drive/MyDrive/aCidadeAlgoritmica/SPINE-GPEv7/05_outputs/tables/pnad_covid/pnad_covid_c014_position_delivery_month_20260721T020957Z.csv",
#   "artifact_hashes": {
#     "cells": "e769e1de8cf218360d73a08b95b55b5ae86082cdaad5bf7b1855b7fafae100f0",
#     "month": "a1d79ed4d11e0686aa833b9d067565474f00311da6bb768906185560b0efe987",
#     "type": "ba1c0644c4c27310e2386be25c7a92b2d580ee73a73490db34c0f0de1c6da693",
#     "position": "98098cc7a4404b304a5f6282f6cb556751fdb3bf278dfb7920f3bf1dfc2125eb",
#     "association": "deacd793b34b975b55ec70816c1399110224caf706a3be1a7a1f4701fb7d801d",
#     "audit_json": "31201752223019a42b11a42d0c2fff878540664f93fbb4890e7f9d4cc1582f69",
#     "report": "bc1881f20f793d37f39f031fb9cca0d3266cc8b1183cdf2e8a6533e02fc99f4f"
#   },
#   "created_at_utc": "2026-07-21T02:10:19.886041+00:00"
# }
# STATUS: AUDIT_PASSED
# REPORT: /content/drive/MyDrive/aCidadeAlgoritmica/SPINE-GPEv7/06_reports/pnad_covid_certification/pnad_covid_c014_audit_report_20260721T020957Z.md
# POSITION TABLE: /content/drive/MyDrive/aCidadeAlgoritmica/SPINE-GPEv7/05_outputs/tables/pnad_covid/pnad_covid_c014_position_delivery_month_20260721T020957Z.csv
# FREEZE: /content/drive/MyDrive/aCidadeAlgoritmica/SPINE-GPEv7/00_admin/PNAD_COVID_CORE_FREEZE.json
#
#
# Exit code: 0

# %%
LOCK = ROOT / '00_admin' / 'PNAD_COVID_C014_AUDIT_LOCK.json'
FREEZE = ROOT / '00_admin' / 'PNAD_COVID_CORE_FREEZE.json'
lock = json.loads(LOCK.read_text(encoding='utf-8'))
freeze = json.loads(FREEZE.read_text(encoding='utf-8'))
print(json.dumps(lock, ensure_ascii=False, indent=2))
print(json.dumps(freeze, ensure_ascii=False, indent=2))
assert lock['status'] == 'AUDIT_PASSED'
assert freeze['status'] == 'FROZEN'
# Out:
# {
#   "run_id": "20260721T020957Z",
#   "script_version": "1.0.0",
#   "audit_schema_version": "spine-gpe-v7-pnad-covid-c014-audit-1.0.0",
#   "status": "AUDIT_PASSED",
#   "critical_failures": [],
#   "warnings": [
#     {
#       "test_id": "2020m05.c014.coverage",
#       "status": "WARN",
#       "severity": "high",
#       "message": "Cobertura C014 abaixo de 95%; interpretação permanece condicional às respostas válidas.",
#       "observed": 65.2241112828439,
#       "expected": ">=95%",
#       "evidence": null
#     },
#     {
#       "test_id": "2020m06.c014.coverage",
#       "status": "WARN",
#       "severity": "high",
#       "message": "Cobertura C014 abaixo de 95%; interpretação permanece condicional às respostas válidas.",
#       "observed": 66.11151339608979,
#       "expected": ">=95%",
#       "evidence": null
#     },
#     {
#       "test_id": "2020m07.c014.coverage",
#       "status": "WARN",
#       "severity": "high",
#       "message": "Cobertura C014 abaixo de 95%; interpretação permanece condicional às respostas válidas.",
#       "observed": 67.38044254104211,
#       "expected": ">=95%",
#       "evidence": null
#     },
#     {
#       "test_id": "2020m08.c014.coverage",
#       "status": "WARN",
#       "severity": "high",
#       "message": "Cobertura C014 abaixo de 95%; interpretação permanece condicional às respostas válidas.",
#       "observed": 66.27747252747253,
#       "expected": ">=95%",
#       "evidence": null
#     },
#     {
#       "test_id": "2020m09.c014.coverage",
#       "status": "WARN",
#       "severity": "high",
#       "message": "Cobertura C014 abaixo de 95%; interpretação permanece condicional às respostas válidas.",
#       "observed": 66.04296604296604,
#       "expected": ">=95%",
#       "evidence": null
#     },
#     {
#       "test_id": "2020m10.c014.coverage",
#       "status": "WARN",
#       "severity": "high",
#       "message": "Cobertura C014 abaixo de 95%; interpretação permanece condicional às respostas válidas.",
#       "observed": 67.67746381805651,
#       "expected": ">=95%",
#       "evidence": null
#     },
#     {
#       "test_id": "2020m11.c014.coverage",
#       "status": "WARN",
#       "severity": "high",
#       "message": "Cobertura C014 abaixo de 95%; interpretação permanece condicional às respostas válidas.",
#       "observed": 68.1046676096181,
#       "expected": ">=95%",
#       "evidence": null
#     }
#   ],
#   "input": "/content/drive/MyDrive/aCidadeAlgoritmica/SPINE-GPEv7/03_processed/20_pnad_covid_certified/certified_pnad_covid_delivery_2020_m05_m11_20260721T010633Z.parquet",
#   "input_sha256": "44af48a4ee05185778d264f528cf9e29863370ad038cfce6eeb10f174ff819ab",
#   "report": "/content/drive/MyDrive/aCidadeAlgoritmica/SPINE-GPEv7/06_reports/pnad_covid_certification/pnad_covid_c014_audit_report_20260721T020957Z.md",
#   "audit_json": "/content/drive/MyDrive/aCidadeAlgoritmica/SPINE-GPEv7/00_admin/registry/pnad_covid_c014_universe_audit_20260721T020957Z.json",
#   "position_delivery_month": "/content/drive/MyDrive/aCidadeAlgoritmica/SPINE-GPEv7/05_outputs/tables/pnad_covid/pnad_covid_c014_position_delivery_month_20260721T020957Z.csv",
#   "artifact_hashes": {
#     "cells": "e769e1de8cf218360d73a08b95b55b5ae86082cdaad5bf7b1855b7fafae100f0",
#     "month": "a1d79ed4d11e0686aa833b9d067565474f00311da6bb768906185560b0efe987",
#     "type": "ba1c0644c4c27310e2386be25c7a92b2d580ee73a73490db34c0f0de1c6da693",
#     "position": "98098cc7a4404b304a5f6282f6cb556751fdb3bf278dfb7920f3bf1dfc2125eb",
#     "association": "deacd793b34b975b55ec70816c1399110224caf706a3be1a7a1f4701fb7d801d",
#     "audit_json": "31201752223019a42b11a42d0c2fff878540664f93fbb4890e7f9d4cc1582f69",
#     "report": "bc1881f20f793d37f39f031fb9cca0d3266cc8b1183cdf2e8a6533e02fc99f4f"
#   },
#   "created_at_utc": "2026-07-21T02:10:19.886041+00:00"
# }
# {
#   "freeze_id": "20260721T020957Z",
#   "status": "FROZEN",
#   "component": "PNAD_COVID_2020_CORE",
#   "core_certification_status": "CERTIFIED",
#   "core_certification_run_id": "20260721T010633Z",
#   "immutable_parquet": "/content/drive/MyDrive/aCidadeAlgoritmica/SPINE-GPEv7/03_processed/20_pnad_covid_certified/certified_pnad_covid_delivery_2020_m05_m11_20260721T010633Z.parquet",
#   "immutable_parquet_sha256": "44af48a4ee05185778d264f528cf9e29863370ad038cfce6eeb10f174ff819ab",
#   "c014_audit_lock": "/content/drive/MyDrive/aCidadeAlgoritmica/SPINE-GPEv7/00_admin/PNAD_COVID_C014_AUDIT_LOCK.json",
#   "c014_audit_report": "/content/drive/MyDrive/aCidadeAlgoritmica/SPINE-GPEv7/06_reports/pnad_covid_certification/pnad_covid_c014_audit_report_20260721T020957Z.md",
#   "social_security_claim_ceiling": "Contribuição previdenciária entre entregadores com resposta válida em C014; cobertura reportada por mês, C007 e C007C.",
#   "epistemic_limit": "C007C=16/17 observa ocupação de entrega; plataforma direta permanece não observada.",
#   "read_only": true,
#   "created_at_utc": "2026-07-21T02:10:19.895542+00:00"
# }

# %%
import pandas as pd
table = pd.read_csv(lock['position_delivery_month'])
display(table)
# Out:
#     reference_month   delivery_type  position_code  position_self_employed  \
# 0                 5  goods_delivery              4                   False
# 1                 5  goods_delivery              5                   False
# 2                 5  goods_delivery              6                   False
# 3                 5  goods_delivery              7                    True
# 4                 5  goods_delivery              8                   False
# ..              ...             ...            ...                     ...
# 62               11  goods_delivery              8                   False
# 63               11         motoboy              4                   False
# 64               11         motoboy              5                   False
# 65               11         motoboy              6                   False
# 66               11         motoboy              7                    True
#
#     n_delivery  weighted_delivery  n_c014_valid  n_c014_missing  \
# 0          576      383864.150574           248             328
# 1           21       16294.136804             4              17
# 2           12        7072.405331            12               0
# 3          303      221582.809067           303               0
# 4           20       17085.195836            20               0
# ..         ...                ...           ...             ...
# 62          17        7630.976739            17               0
# 63         164      113796.876261            64             100
# 64           3        1132.437382             1               2
# 65           1         561.485445             1               0
# 66         224      160567.843130           224               0
#
#     weighted_c014_valid  weighted_c014_missing  \
# 0         164562.596177          219301.554397
# 1           1741.004467           14553.132336
# 2           7072.405331               0.000000
# 3         221582.809067               0.000000
# 4          17085.195836               0.000000
# ..                  ...                    ...
# 62          7630.976739               0.000000
# 63         51910.044002           61886.832259
# 64           688.242402             444.194980
# 65           561.485445               0.000000
# 66        160567.843130               0.000000
#
#     c014_coverage_percent_unweighted  c014_coverage_percent_weighted  \
# 0                          43.055556                       42.870009
# 1                          19.047619                       10.684852
# 2                         100.000000                      100.000000
# 3                         100.000000                      100.000000
# 4                         100.000000                      100.000000
# ..                               ...                             ...
# 62                        100.000000                      100.000000
# 63                         39.024390                       45.616405
# 64                         33.333333                       60.775316
# 65                        100.000000                      100.000000
# 66                        100.000000                      100.000000
#
#     n_contributor  n_noncontributor  weighted_contributor  \
# 0              32               216          27243.821710
# 1               2                 2            845.005100
# 2               6                 6           4555.164263
# 3              90               213          70855.067058
# 4               5                15           5460.811855
# ..            ...               ...                   ...
# 62              1                16            717.229956
# 63             12                52          12130.247215
# 64              0                 1              0.000000
# 65              1                 0            561.485445
# 66             58               166          37385.207810
#
#     weighted_noncontributor  contribution_percent_among_valid_unweighted  \
# 0             137318.774467                                    12.903226
# 1                895.999367                                    50.000000
# 2               2517.241068                                    50.000000
# 3             150727.742008                                    29.702970
# 4              11624.383981                                    25.000000
# ..                      ...                                          ...
# 62              6913.746783                                     5.882353
# 63             39779.796787                                    18.750000
# 64               688.242402                                     0.000000
# 65                 0.000000                                   100.000000
# 66            123182.635320                                    25.892857
#
#     contribution_percent_among_valid_weighted
# 0                                   16.555294
# 1                                   48.535493
# 2                                   64.407568
# 3                                   31.976789
# 4                                   31.962243
# ..                                        ...
# 62                                   9.398927
# 63                                  23.367823
# 64                                   0.000000
# 65                                 100.000000
# 66                                  23.283123
#
# [67 rows x 18 columns]
